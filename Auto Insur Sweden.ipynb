# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("AutoInsurSweden.txt",sep="\t",decimal=",")

# %%
data.head()
# Out:
#      X      Y
# 0  108  392.5
# 1   19   46.2
# 2   13   15.7
# 3  124  422.2
# 4   40  119.4

# %% [markdown]
# ## 2-D Scatter Plot

# %%
data.plot(kind='scatter', x='X', y='Y')

# %% [markdown]
# ## Pair Plot

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(data, hue="Y", size=3);
plt.show()
# Out:
# C:\Users\Chetan Jain\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Mean and Std-dev

# %%
print("Means:")
print(np.mean(data["X"]))
print(np.mean(data["Y"]))

print("\nStd-dev:");
print(np.std(data["X"]))
print(np.std(data["Y"]))
# Out:
# Means:
# 22.904761904761905
# 98.18730158730159
#
# Std-dev:
# 23.165871370874054
# 86.63170447187734

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(data)
centroids = kmeans.cluster_centers_

# %%
fig = plt.figure(figsize=(5, 5))

colors = map(lambda x: colmap[x+1], labels)

plt.scatter(data['X'], data['Y'],  alpha=0.5, edgecolor='k')
for idx, centroid in enumerate(centroids):
    plt.scatter(*centroid)
plt.xlim(0, 80)
plt.ylim(0, 80)
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(data)
centroids = kmeans.cluster_centers_

# %%
fig = plt.figure(figsize=(5, 5))

colors = map(lambda x: colmap[x+1], labels)

plt.scatter(data['X'], data['Y'],  alpha=0.5, edgecolor='k')
for idx, centroid in enumerate(centroids):
    plt.scatter(*centroid)
plt.xlim(0, 80)
plt.ylim(0, 80)
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=9)
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=9, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(data)
centroids = kmeans.cluster_centers_

# %%
fig = plt.figure(figsize=(5, 5))

colors = map(lambda x: colmap[x+1], labels)

plt.scatter(data['X'], data['Y'],  alpha=0.5, edgecolor='k')
for idx, centroid in enumerate(centroids):
    plt.scatter(*centroid)
plt.xlim(0, 80)
plt.ylim(0, 80)
plt.show()
